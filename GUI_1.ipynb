# %%
from random import randint
from Tkinter import *
from collections import OrderedDict
from tkinter import *
import Tkinter as tk     # python 2
import tkFont as tkfont  # python 2

lessons = ('basic vocab', 'gender of words', 'demonstrative', 'word order agreement',
           'present tense & irregulars/stem changers', 'ser vs estar',
           'posessive pronouns', 'reflexive verbs', 'verbs like gustar',
           'gerund & progressive', 'adverbs', 'superlatives', 'preterite & car,gar,zar', 'imperfect',
           'hacer/past participle', 'conditional & irregulars', 'passive voice',
           'impersonal se', 'commands', 'present perfect', 'subjunctive')
           
vocabulary = ('school work', 'greetings', 'descriptions', 'numbers', 'family',
              'health', 'class subjects', 'hobbies', 'routines', 'navigation',
              'art', 'science & technology', 'medical', 'society', 'government',
              'nature', 'conventional sports', 'activities')
              
class vocabulary_Lesson():
  #Displays a list of spanish words and their english translation
    def __init__(self, subject, contents):
        self.sub = subject
        self.con = contents
        #subject refers to an entry made in the vocabulary tuple
    
    def print_Subject(self):
        print ('This unit\'s topic is: ' + self.sub)
  
    def display_Contents(self):
        for k, v in self.con.iteritems():
            print(k, v)
      
    def start_Flashcards(self):
        print ('Please enter the number of the mode of practice: \n1: Spanish to English \n2: English to Spanish \n3: Mixed')
        mode = input()
        tries = 0 #tries tracks the amount of incorrect guesses
        if ((mode != 1) and (mode != 2) and (mode != 3)):
            print ('Error: Please enter a valid number for the mode of practice:')
            self.start_Flashcards()
      
        elif (mode == 1):
            tries = 0
            words = -1
            for key in self.con:
                words = words + 1
                print (key)
                print ('Please enter the English translation of the above word: ')
                print ('To stop the exercise at any time, enter: Stop')
                response = raw_input()
                if (response.lower() == 'stop'):
                    break
                elif (response.lower() != self.con[key].lower()):
                    tries = tries + 1
                    sec_response = raw_input('Incorrect, please try again.\n')
                if (sec_response.lower() == 'stop'):
                    break
                elif (sec_response.lower() != self.con[key].lower()):
                    tries = tries + 1
                    print ('Incorrect, the correct answer is: ' + self.con[key])
            print ('You have passed through ' + str(words) + ' words with ' + str(tries) + ' error(s).')      
      
        elif (mode == 2):
            tries = 0
            words = -1
            for key in self.con:
                words = words + 1
                print (self.con[key])
                print ('Please enter the Spanish translation of the above word: ')
                print ('To stop the exercise at any time, enter: Stop')
                response = raw_input()
                if (response.lower() == 'stop'):
                    break
                elif (response.lower() != key.lower()):
                    tries = tries + 1
                    sec_response = raw_input('Incorrect, please try again.\n')
                if (sec_response.lower() == 'stop'):
                    break
                elif (sec_response.lower() != key.lower()):
                    tries = tries + 1
                    print ('Incorrect, the correct answer is: ' + key)
            print ('You have passed through ' + str(words) + ' words with ' + str(tries) + ' error(s).')  
            
        #mixed Spanish and English    
        elif (mode == 3):
            tries = 0
            words = -1
            for key in self.con:
                words = words + 1
                determiner = randint(0,1)
                if (determiner == 0):
                    print (self.con[key])
                else:
                    print (key)
                print ('Please enter the translation of the above word: ')
                print ('To stop the exercise at any time, enter: Stop')
                response = raw_input()
                if (response.lower() == 'stop'):
                    break
                elif ( ((determiner != 0) and (sec_response.lower() != self.con[key].lower())) or ((determiner != 1) and (sec_response.lower() != key.lower())) ):
                    tries = tries + 1
                    sec_response = raw_input('Incorrect, please try again.\n')
                elif (sec_response.lower() == 'stop'):
                    break
                if ( ((determiner != 0) and (sec_response.lower() != self.con[key].lower())) or ((determiner != 1) and (sec_response.lower() != key.lower())) ):
                    tries = tries + 1
                    print ('Incorrect, the correct answer is: ' + key + ' <-> ' + self.con[key])
            print ('You have passed through ' + str(words) + ' words with ' + str(tries) + ' error(s).')

        
class grammer_Lesson():
  
  def __init__(self, subject):
    self.sub = subject
    
    
    
    
#Vocabulary lesson topics and dictionaries

words_School_Work = OrderedDict([('Tarea', 'Homework'), ('Libro', 'Book'), ('Clase', 'Class'), ('Semestre', 'Semester'),
                    ('Tomar apuntes', 'To take notes'), ('Suspender', 'To fail'), ('Universidad', 'University'),
                    ('Cursos', 'Courses'), ('Director', 'Principle'), ('Estudiar', 'To study'),
                    ('Maestro', 'Teacher'), ('Profesor', 'Professor'), ('Consejero', 'Guidance counselor'),
                    ('Detalle', 'Detail'), ('Escribir', 'To write'), ('Prestar atención', 'To pay attention'),
                    ('Papel', 'Paper'), ('Ensayo', 'Essay'), ('Proyecto', 'Project'), ('Leer', 'To read'),
                    ('Periodo', 'Period'), ('Problema', 'Problem'), ('Tema', 'Subject'), ('Razón', 'Reason'),
                    ('Correcto', 'Corect'), ('Fuente', 'Source'), ('Escuela', 'School'), ('Lápiz', 'Pencil'),
                    ('Libro', 'Book'), ('Cuaderno', 'Notebook'), ('Escritorio', 'Desk'), ('Computadora', 'Computer'),
                    ('Pluma', 'Pen'), ('Examen', 'Exam'), ('Prueba', 'Quiz'), ('Lección', 'Lesson'), ('Diploma', 'Diploma'),
                    ('Título', 'Degree'), ('Diccionario', 'Dictionary')])


words_Greetings = OrderedDict([('Hola', 'Hello'), ('¿Qué tal?', 'What\'s up'), ('Buenas días', 'Good morning'),
                  ('Buenas tardes', 'Good afternoon'), ('Buenas noches', 'Good evening'),
                  ('Me llamo', 'My name is'), ('¿Y usted?', 'And you?'), ('Lo siento', 'Sorry'),
                  ('Mucho gusto', 'Nice to meet you'), ('Encantado', 'Pleased to meet you'), ('Muy bien', 'Very well'),
                  ('Sí', 'Yes'), ('No', 'No'), ('Hasta mañana', 'See you tomorrow'), ('Hasta luego', 'See you later'),
                  ('Adiós', 'Goodbye'), ('Gracias', 'Thank you'), ('Muchas gracias', 'Thank you very much'),
                  ('Bienvenidos', 'Welcome'), ('Yo soy de', 'I am from')])

words_Descriptions = OrderedDict([('Gran', 'Large'), ('Bueno', 'Good'), ('Inteligente', 'Intelligent'), ('Gracioso', 'Funny'),
                     ('Loco', 'Crazy'), ('Brillante', 'Bright'), ('Adolescente', 'Adolescent'), ('Serio', 'Serious'),
                     ('Amable', 'Pleasant'), ('Divertido', 'Fun'), ('Antipático', 'Mean'), ('Estúpido', 'Stupid'),
                     ('Genuino', 'Genuine'), ('Feliz', 'Happy'), ('Malo', 'Bad'), ('Perfecto', 'Perfect'),
                     ('Triste', 'Sad'), ('Alto', 'Tall'), ('Bajo', 'Short'), ('Grande', 'Big'), ('Pequeño', 'Small'),
                     ('Simple', 'Simple'), ('Complicado', 'Complicated'), ('Aburrido', 'Boring'), ('Nuevo', 'New'),
                     ('Viejo', 'Old'), ('Rico', 'Rich'), ('Pobre', 'Poor'), ('Caluroso', 'Hot'), ('Frió', 'Cold'),
                     ('Caro', 'Expensive'), ('Barato', 'Cheap'), ('Rápido', 'Fast'), ('Lento', 'Slow'), ('Tarde', 'Late'),
                     ('Tempraño', 'Early'), ('Fuerte', 'Strong'), ('Débil', 'Weak'), ('Enfermo', 'Sick'),
                     ('Sano', 'Healthy'), ('Limpio', 'Clean'), ('Sucio', 'Dirty'), ('Junto', 'Together'),
                     ('Solo', 'Alone'), ('Injusto', 'Unfair'), ('Justo', 'Fair')])

words_Numbers = OrderedDict([('Número', 'Number'), ('Primo', 'Prime'), ('Par', 'Even'), ('Impar', 'Odd'), ('Cero', 'Zero'),
                ('Uno', 'One'), ('Dos', 'Two'), ('Tres', 'Three'), ('Cuatro', 'Four'), ('Cinco', 'Five'),
                ('Seis', 'Six'), ('Siete', 'Seven'), ('Ocho', 'Eight'), ('Nueve', 'Nine'), ('Diez', 'Ten'),
                ('Once', 'Eleven'), ('Doce', 'Twelve'), ('Trece', 'Thirteen'), ('Catorce', 'Fourteen'),
                ('Quince', 'Fifteen'), ('Dieciséis', 'Sixteen'), ('Diecisiete', 'Seventeen'),
                ('Dieciocho', 'Eighteen'), ('Diecinueve', 'Nineteen'), ('Veinte', 'Twenty'),
                ('Veintiuno', 'Twenty one'), ('Veintidos', 'Twenty dos'), ('Treinta', 'Thirty'),
                ('Treinta y uno', 'Thirty one'), ('Cuarenta', 'Fourty'), ('Cuarenta y uno', 'Fourty one'),
                ('Cincuenta', 'Fifty'), ('Sesenta', 'Sixty'), ('Setenta', 'Seventy'), ('Ochenta', 'Eighty'),
                ('Noventa', 'Ninety'), ('Cien', 'Hundred'), ('Ciento uno', 'Hundred and one'), 
                ('Doscientos', 'Two hundred'), ('Trescientos', 'Three hundred'), ('Quincientos', 'Five hundred'),
                ('Setecientos', 'Seven hundred'), ('Novescientos', 'Nine hundred'), ('Mil', 'Thousand'),
                ('Dos mil', 'Two thousand'), ('Millón', 'Million'), ('Dos millón', 'Two million')])

words_Family = OrderedDict([('Madre', 'Mother'), ('Padre', 'Father'), ('Hermano', 'Brother'), ('Hermana', 'Sister'),
               ('Bebé', 'Baby'), ('Hijo', 'Son'), ('Hija', 'Daughter'), ('Abuela', 'Grandmother'),
               ('Abuelo', 'Grandfather'), ('Bisabuela', 'Great Grandmother'), ('Bisabuelo', 'Great Grandfather'),
               ('Tío', 'Uncle'), ('Tía', 'Aunt'), ('Tío abuelo', 'Great Uncle'), ('Tía abuela', 'Great Aunt'),
               ('Primo', 'Cousin'), ('Sobrino', 'Nephew'), ('Sobrina', 'Niece'), ('Suegro', 'Father in law'),
               ('Suegra', 'Mother in law'), ('Yerno', 'Son in law'), ('Nuera', 'Daughter in law'),
               ('Cuñado', 'Brother in law'), ('Cuñada', 'Sister in law'), ('Medio hermano', 'Half brother'),
               ('Medio hermana', 'Half sister'), ('Hermanastra', 'Stepsister'), ('Hermanastro', 'Stepbrother'),
               ('Hijastro', 'Stepson'), ('Hijastra', 'Stepdaughter'), ('Padrastro', 'Stepfather'), ('Madrastro', 'Stepmother')])

words_Health = OrderedDict([('Doctor', 'Doctor'), ('Médico', 'Medic'), ('Hospital', 'Hospital'), ('Ambulancia', 'Ambulance'),
               ('Farmacia', 'Pharmacy'), ('Inyección', 'Injection'), ('Medicina', 'Medicine'),
               ('Ejercicio', 'Exercise'), ('Dormir', 'To sleep'), ('Descanso', 'Rest'), ('Dieta', 'Diet'),
               ('Herida', 'Injury'), ('Recuperar', 'To recover'), ('Estrés', 'Stress'), ('Mental', 'Mental'),
               ('Físico', 'Physical'), ('Sanidad', 'Healthiness'), ('Hidratar', 'To hydrate'),
               ('Primeros auxilios', 'First aid'), ('Dolor', 'Pain'), ('Tratamiento', 'Treatment'),
               ('Alergia', 'Allergy'), ('Gripe', 'Flu'), ('Fiebre', 'Fever'), ('Quemadura', 'Burn'),
               ('Tos', 'Cough'), ('Cabeza', 'Head'), ('Corazón', 'Heart'), ('Estómago', 'Stomach'),
               ('Espalda', 'Back'), ('Brazo', 'Arm'), ('Mano', 'Hand'), ('Ojo', 'Eye'), ('Oreja', 'Ear'),
               ('Dolor de cabeza', 'Headache'), ('Higiene', 'Hygiene'), ('Microbios', 'Germs'),
               ('Paciente', 'Patient'), ('Sindrome', 'Syndrome'), ('Síntomas', 'Symptoms'), ('Terapia', 'Therapy')])

words_Class_Subjects = OrderedDict([('Matemáticas', 'Mathematics'), ('Físicas', 'Physics'), ('Español', 'Spanish'),
                       ('Banda', 'Band'), ('Música', 'Music'), ('Arte', 'Art'), ('Ciencias', 'Science'), ('Ciencias sociales', 'Scoial sciences'),
                       ('Economía', 'Economics'), ('Historia', 'History'), ('Informática', 'Computer science'),
                       ('Idioma extranjero', 'Foreign Language'), ('Inglés', 'English'), ('Cálculo', 'Calculus'),
                       ('Educación física', 'Physical education'), ('Biología', 'Biology'), ('Geografía', 'Geography'),
                       ('Álgebra', 'Algebra'), ('Química', 'Chemistry'), ('Asuntos', 'Subjects'),
                       ('Recreo', 'Recess'), ('Ingeniería', 'Engineering'), ('Lituratura', 'Literature'),
                       ('Almuerzo', 'Lunch'), ('Consultivo', 'Advisory')])

words_Hobbies = OrderedDict([('Pasatiempo', 'Hobby'),  ('Cocinar', 'To cook'), ('dibujo', 'drawing'), 
                             ('pesca', 'fishing'), ('tejer', 'to crochet'), ('edificio', 'building'),
                             ('escritura', 'writing'), ('lectura', 'reading'), ('juger con videojuegos', 'to play videogames'),
                             ('coser', 'to sew'), ('tocando instrumentos', 'playing instruments'), ('recoger', 'to collect')])
                            
words_Routines =  OrderedDict([('rutina', 'routine'), ('horario', 'schedule'), ('ejercicio', 'exercise'), ('estriramiento', 'stretching'), 
                               ('comer desayuno', 'to eat breakfast'), ('comer almuerzo', 'to eat lunch'), ('comer cena', 'to eat dinner'),
                               ('programación', 'scheduling'), ('cepillarse los dientes', "to brush one's teeth"), ('bañarse', 'to bath'), 
                               ('ducharse', 'to shower'), ('ir a la escuela', 'to go to school'), ('ir a trabajar', 'to go to work'), ('ir a casa', 'to go home'), 
                               ('ir a dormir', 'to go to sleep'), ('despertar', 'to wake up')])

words_Navigation = OrderedDict([('navegación', 'navigation'), ('mapa', 'map'), ('sistema de posicionamiento global', 'GPS system'),
                                ('mundo', 'world'), ('geografía', 'geography'), ('océano', 'ocean'),
                                ('mar', 'sea'), ('lago', 'lake'), ('estanque', 'pond'), ('río', 'river'), ('canal', 'canal'), ('carretera', 'highway'),
                                ('calle', 'street'), ('avenida', 'avenue'), ('ubicación', 'location'), ('esquina', 'corner'), ('barco', 'boat'), ('vehiculo', 'vehicle'),
                                ('navío', 'ship'), ('coche', 'car'), ('camión', 'truck'), ('avión', 'plane'), ('aerolínea', 'airline'), ('satélite', 'satellite'),
                                ('dirección', 'direction'), ('adelante', 'forward'), ('izquierda', 'left'), ('derecho', 'right'), ('encima', 'above'),
                                ('abajo', 'below'), ('al lado de', 'beside'), ('cerca', 'near'), ('milla', 'mile'), ('metro', 'meter'),
                                ('pies', 'feet'), ('viaje', 'commute'), ('destino', 'destination'), ('empezar', 'start'), ('viaje', 'trip'),
                                ('transporte', 'transport'), ('transporte público', 'public transportation'), ('autobús', 'bus'),
                                ('tren', 'train'), ('express', 'express')])

words_Art = OrderedDict([ ('arte', 'art'), ('pintar', 'to paint'), ('suministros de arte', 'art supplies'),
                         ('imagen', 'picture'), ('tejido', 'fabric'), ('tela', 'canvas'),
                         ('pincel', 'paint brush'), ('tienda de artesanías', 'crafts store'), ('colores de aqua', 'water colors'),
                         ('crayones', 'crayons'), ('marcadores', 'markers'), ('examen', 'paper'),
                         ('artesanía', 'crafts'), ('hilo', 'yarn'), ('escultura', 'sculpture'),
                         ('ejemplar', 'to model'), ('material', 'material'), ('color', 'color'), ('tono', 'hue')])

words_Science_Tech = OrderedDict([('química', 'chemistry'), ('elementos', 'elements'), ('energía', 'energy'), ('molécula', 'molecule'),
                                  ('compuesto', 'compound'), ('gas', 'gas'), ('líquido', 'liquid'), ('sólido', 'solid'),
                                  ('átomo', 'atom'), ('químico', 'chemical'), ('reacción', 'reaction'), ('biología', 'biology'),
                                  ('evolución', 'evolution'), ('población', 'population'), ('genes', 'genes'), ('hereditario', 'hereditary'),
                                  ('biológico', 'biological'), ('especies', 'species'), ('órgano', 'organ'), ('sistema de órganos', 'organ system'),
                                  ('tejido', 'tissue'), ('células', 'cells'), ('orgánulos', 'organelles'), ('física', 'physics'),
                                  ('partícula', 'particle'), ('repartido', 'speed'), ('velocidad', 'velocity'),
                                  ('fuerza', 'force'), ('electricidad', 'electricty'), ('magnetismo', 'magnetism'), ('atracción', 'attraction'),
                                  ('gravedad', 'gravity'), ('atracción', 'acceleration'), ('bioquímica', 'biochemistry'),
                                  ('química orgánica', 'organic chemistry'), ('ciencias de la computación', 'computer science'),
                                  ('computadora', 'computer'), ('tecnología', 'technoloy'), ('conexión a internet', 'internet connection'),
                                  ('datos', 'data'), ('programa de computadora', 'computer program'), ('ingeniero', 'enginner'), ('software', 'software')])

words_Medical = OrderedDict([('Dolorido', 'In Pain'), ('Cirugía', 'Surgery'), ('Contagioso', 'Contagious'),
                             ('Diagnosticar', 'To diagnose'), ('Efectos adversos', 'Adverse effects'),
                             ('Embarazo', 'Pregnancy'), ('Fiebre', 'Fever'), ('Epidemia', 'Epidemic'),
                             ('Gripe', 'Flu'), ('Hierbas medicionales', 'Medicinal herbs'), ('Higiene', 'Hygene'),
                             ('Hinchar', 'To swell'), ('Influenza', 'Influenza'), ('Insomnio', 'Insomnia'),
                             ('Medicinas alternativas', 'Alternative medicines'), ('Microbios', 'Germs'),
                             ('Obesida', 'Obesity'), ('Paciente', 'Patient'), ('Padecer de', 'To suffer from'),
                             ('Pastillas', 'Pills'), ('Receta', 'Prescription'), ('Resfriado', 'A cold'),
                             ('saludable', 'Healthy'), ('Sano', 'Healthy'), ('Sindrome', 'Syndrome'),
                             ('Sobrepeso', 'Overweight'), ('terapia', 'therapy'), ('tratamientos', 'treatments')])

words_Government = OrderedDict([('gobierno', 'government'), ('relaciones internacionales', 'international relations'),
                                ('presidente', 'president'), ('gobernador', 'governor'), 
                                ('política', 'politics'), ('votar', 'vote'), 
                                ('independencia', 'independence'), ('elección', 'election'), 
                                ('ley', 'law'), ('país', 'country'), ('estado', 'state'), 
                                ('distrito', 'district')
            
                               ])


words_Society = OrderedDict([('Amistad', 'Friendship'), ('Anciano', 'Elderly'), ('Avances', 'Advamcements'),
                             ('Calidad de vida', 'Quality of life'), ('Caridad', 'Charity'), ('Crimen', 'Crime'),
                             ('Derechos humanos', 'Human rights'), ('Desigualdad', 'Inequality'),
                             ('Desplazado', 'Desplaced'), ('Discapacidad', 'Disabled'), ('Pobreza', 'Poverty'),
                             ('Refugio politico', 'Political asylum'), ('Sanidad', 'Health'), ('Seguridad', 'Security'),
                             ('Viuda', 'Widow')])



words_Nature = OrderedDict([('Ambiente', 'Atmosphere'), ('Calentamiento global', 'Global warming'),
                            ('Capa de ozono', 'Ozone layer'), ('Combustibles', 'Fuel'), ('Derretimiento', 'Melting'),
                            ('Desechos', 'Wastes'), ('Efecto invernadero', 'Greenhouse effect'), ('Entorno', 'Environment'),
                            ('Extinguirse', 'To become extinct'), ('Glaciar', 'glacier'), ('Huella de carbono', 'Carbon footprint'),
                            ('Masa polar', 'Polar ice cap'), ('Petroleo', 'Oil'), ('Placas', 'Plates'), ('Reciclaje', 'Recycling'),
                            ('Reciclar', 'to recycle'), ('Recursos', 'Resources'), ('Recursos renovables', 'Renewable resources')])

words_Conventional_Sports = OrderedDict([('Deportes', 'Sports'), ('bádminton', 'badminton'), ('Béisbol', 'Baseball'), ('Basquetbol', 'Basketball'),
                                         ('boxeo', 'boxing'), ('críquet', 'cricket'), ('futbol americano', 'football'),('golf', 'golf'), 
                                         ('hockey', 'hockey'), ('kickboxing', 'kickboxing'), ('lacrosse', 'lacrosse'), ('tenis de mesa', 'table tennis'), 
                                         ('ráquetbol ', 'racquetball'), ('ráquetbol ', 'racquetball'), ('squash', 'squash'), ('tenis', 'tennis'),
                                         ('sóftbol', 'softball'), ('fútbol', 'soccer'), ('atletismo', 'track and field'), ('voleibol', 'volleyball'),
                                         ('polo', 'polo'), ('polo acuático', 'water polo'), ('croquet', 'croquet'), ('esgrima', 'fencing')])

words_Activities = OrderedDict([('discusión ', 'debating'), ('Tiro con arco', 'Archery'), ('Excursionismo con mochila', 'Backpacking'), 
                             ('Ciclismo', 'Biking'), ('billar', 'billiards'), ('paseo en barco', 'boating'), 
                             ('culturismo ', 'bodybuilding'), ('boliche', 'bowling'),
                             ('acampada', 'camping'), ('canotaje', 'canoeing'), 
                             ('dardos', 'darts'), ('ejercicio', 'exercise'),
                             ('pesca', 'fishing'), ('disco', 'discus'), 
                             ('gimnasia', 'gymnastics'), ('aladeltismo', 'hang gliding'), ('excursionismo', 'hiking'), 
                             ('caza', 'hunting'), ('kárate', 'karate'), 
                             ('artes marciales', 'martial arts'), ('motociclismo', 'motorcycling'), 
                             ('paintball', 'paintball'), ('parapente', 'paragliding'), 
                             ('alpinismo', 'mountaineering'), ('vela', 'sailing'), 
                             ('buceo', 'diving'), ('tiro al blanco', 'target shooting'), ('hacer skate', 'skateboarding'),
                             ('patinaje', 'skating'), ('Salto a paracaídas', 'Parachuting'), ('buceo con esnórquel', 'snorkeling'), ('Snowboard', 'Snowboarding'),
                             ('esquí', 'skiing'), ('surf', 'surfing'), ('natación', 'swimming'),
                             ('lucha libre', 'wrestling')])


text_Structure = ['Welcome to an introductory Spanish education. This first lesson will teach the basic footholds for the following lessons.',
                  'The foundation of the Spanish language is its structure and formatting.',
                  'Spanish is very flexible and diverse in how its users structure their words, but in general, like in English, Spanish has a word order of Subject, Verb, Object.',
                  'For example, in the sentence "I use computers" and its Spanish translation "Yo uso computadoras" both have the the Subject (I, Yo) first, then the Verb (use, uso), and then the Object (computers, computadoras)',
                  'Another aspect of Spanish is that descriptor words are typically place after, not before, the words they describe.',
                  'So while in English we say an "Interesting book" with the adjective before the subject, Spanish speakers say "Libro interesante", putting the adjective after the noun.',
                  'However, none of these will be helpful to you if you do not know any Spanish words to use. So in the following lines, a list of essential words will be displayed.',
                  '"I" = "Yo" \t "You" = "Usted" \t "He" = "Él" \t "She" = "Ella" \n "We" = "Nosotros" \t "You (informal)" = "Tú" \t "You all" = "Ustedes" \t "Them (masculine)" = "Ellos" \t "Them (feminine)"',
                  'We will run through more of the foundations of Spanish in future lessons, but this is adequate for your very first lesson to a new language.']
                                  
                              
                           
                           
text_Gender = ['Spanish uses gendered words, with them either being masculine or feminine.',
               'Nouns in spanish are gendered, and any words relating or decribing them have to use the same gender as the noun.',
               'You can usually tell if a noun is gendered or not with what letters they end in. For example, nouns that end in "-o" will usually be masculine, while nouns ending in "-a", "-dad", or "-ión" are typically feminine.',
               'In addition, the definite article (the equivalent of "the" in English) and the indefinite articles (the equivalent of "a" and "an") also change in accordance to the gender of the noun.',
               'For example, a masculine noun like "libro" (book) would use the definite article "el" and indefinite article "un". So to say "The book" in Spanish, we say "El libro" and to say "A book", we say "Un libro".',
               'With a feminine noun like "persona" (person) would use the definite article "la" and indefinite article "una". To say "The person" in Spanish, we say "La persona" and to say "A person", we say "Una persona".',
               'Also, when describing something, the adjectives and descriptors used must follow the gender of the noun. In addition, when describing a person, the descriptors also change to match the gender of that person.',
               'So to say "a red ball", since "ball" is "pelota" (female), we use the feminine forms of to get "Una pelota roja". To describe a red masculine object, like a bedroom "dormitorio", we would say "Un dormitorio rojo"']
                           
                           
                            
                            
text_Demonstrative = ['Despite the unusual name, the Demonstrative is a concept you should already be quite familiar with.',
                      'It simply means the words used to specify and seperate the things that are being referred to against things that are not.',
                      'If you have trouble understanding, the Demonstratives in English are words like "this", "that", "those" and so on. They distinguish specific objects from all the rest.',
                      'Just like in English, you must take into account the context of the object you are referring to in order to know which Demonstrative word to use.',
                      'Also like with English, demonstrative words come before nouns, not after. They are different from adjectives, which go after the noun.'
                      'In Spanish, the demonstratives change depending on the distance of the object from the speaker. They are equivalent to the English words "This/These", "That/Those", and "That/those over there".',
                      'Additionally, the forms of the demonstratives must adapt to the gender and plurality of the object you are referring to. Fear not, the following lines will finally show these different forms.',
                      'When trying to say "This/These" for something nearby, the Spanish equivalent is "Este" for a single, masculine noun, and "Esta" for a single, feminine noun.',
                      '"Estos" denotes a masculine plural of objects, and "Estas" means a feminine plural.' 
                      'When saying "That/Those" for something not easily accessible to you, use "Ese" for a single, masculine noun, and "Esa" for a single, feminine noun.',
                      '"Esos" denotes a masculine plural, and "Esas" signifies a feminine plural.',
                      'When saying "That/Those" for something very far away, use "Aquel" for a single, masculine noun, and "Aquella" for a single, feminine.',
                      '"Aquellos" is for masculine plurals, and "Aquellas" is for feminine plurals.']
                      #Put examples?
                  
                                   
                                   
text_Present_Tense = ['Verbs in Spanish can be conjugated in a varity of ways, and this lesson will focus on the simple present tense.',
                      'The present tense is used in Spanish to talk about habits, routines, actions taking place, and facts, just like in English.',
                      'The base form of verbs always end in either -ar, -er, or -ir, and the way you conjugate verbs depend on which ending a verb has, as well as who is saying the verb.',
                      'As such, there are many different ways to conjugate verbs, even in just the present tense, but with practice, it will become easy to rememorize and recall them on demand.',
                      'For the present tense, if the subject saying the verb is "Yo" ("I" in English), -ar verbs have their ending replaced with -o, as do -er/-ir verbs.',
                      'For example, to conjugate "Hablar" ("To speak") to be "I speak", it is conjugated as "Hablo", while to conjugate "Vivir" ("To live") to be "I live", use "Vivo".',
                      'If the subject is "Tú" (Informal "You"), -ar verbs use -as, and -er/-ir verbs use -es.',
                      'If the subject is either "Usted" (Formal "You"), "Él" ("He"), or "Ella" ("She"), -ar verbs use -a, and -er/-ir verbs use -e.',
                      'If the subject is "Vosotros" (Informal "You all"), -ar verbs use -áis, and -er/-ir verbs use -éis.',
                      'If the subject is "Nosotros" ("Us"), -ar verbs use -amos, and -er/-ir verbs use -emos.',
                      'If the subject either "Ustedes" (Formal "You all"), "Ellos" (Masculine "They"), or "Ellas" (Feminine "They") -ar verbs use -an, and -er/-ir verbs use -en.',
                      'Again, while it seems complicated now, with time and practive, these will be easily remembered.']
  
                                   
                                   
text_Ser_Estar = ['The verbs "ser" and "estar" both mean "to be", and are used to describe things, however, they are both used in different contexts and carry different implications.',
                  'They are also conjugated differently than other verbs, and are irregular in nearly all of their forms.',
                  'The conjugation for "Ser" is: ("Yo soy"), ("Tú eres"), ("Él/Ella/Usted es"), ("Vosotros sois"), ("Nosotros somos"), and ("Ellos/Ellas/Ustedes son").',
                  'The conjugation for "Estar" is: ("Yo estoy"), ("Tú estás"), ("Él/Ella/Usted está"), ("Vosotros estáis"), ("Nosotros estamos"), and ("Ellos/Ellas/Ustedes están").',
                  'Using "Ser" over "Estar" and vice versa can either be entirely wrong, or can change the meaning of a sentence entirely, so it is important to distinguish their functions.',
                  '"Ser" is to be used when describing permanent or long-lasting characteristics. Think descriptions of essential qualities, the time, professions, character traits, origins and relationships.',
                  '"Estar" is to be used when describing temporary states and locations. It refers to position, location, ongoing actions, emotions, and mental and physical conditions.',
                  'For example, saying "Soy aburrido" means "I am a boring person", but using "Estoy aburrido" means "I am bored".',]
                                   
                                   
text_Possessive = ['The Possessive refers to words that indicate that an object is owned by someone. In English, the equivalents would be "Mine", "Your", "Its", "His", "Hers", and so on.',
                   'In Spanish, there are two sets of possessives, but both change according to the gender and plurality of the noun, similar to the demonstrative.',
                   'Please note that the possessive must match the possessed entity in gender and number, not the possessor, and that the possessive comes before nouns, not after.',
                   'If the owner is "Yo" ("I"), use "Mi" to express ownership of a single object, masculine or feminine, and use "Mis" for multiple objects, masculine or feminine.',
                   'If the owner is "Tú" (Informal "You"), use "Tu" for a single object of any gender, and use "Tus" for mulitple objects of any gender.',
                   'If the owner is either "Usted" (Formal "You"), "Él" ("He"), or "Ella" ("She"), use "Su" for a single object of any gender, and use "Sus" for multiple objects of any gender.',
                   'If the owner is "Vosotros" (Informal "You all"), use "Vuestro" for a single masculine object, "Vuestra" for a single feminine object, and "Vuestros" for multiple masculine objects, and "Vuestras" for multiple feminine objects.',
                   'If the owner is "Nosotros" ("Us"), use "Nuestro" for a single masculine object, "Nuestra" for a single feminine object, and "Nuestros" for multiple masculine objects, and "Nuestras" for multiple feminine objects.',
                   'If the owner is either "Ustedes" (Formal "You all"), "Ellos" (Masculine "They"), or "Ellas" (Feminine "They"), use "Su" for a single object of any gender, and use "Sus" for multiple objects of any gender.',]
                   
                   
                                   
text_Reflexive = ['A reflexive pronoun is a word that indicates that the subject initiating a verb is also the subject of the verb; they are preforming an action on themself.',
                  'In Spanish, like in other types of words, change according to the subject, though they do not change according to gender or plurality.',
                  'When the subject of the verb is "Yo", the reflexive pronoun is "Me".',
                  'When the subject of the verb is "Tú", the reflexive pronoun is "Te".',
                  'When the subject of the verb is either "Usted", "Él", or "Ella", the reflexive pronoun is "Se".',
                  'When the subject of the verb is "Vosotros", the reflexive pronoun is "Os".',   
                  'When the subject of the verb is "Nosotros", the reflexive pronoun is "Nos".', 
                  'When the subject of the verb is either "Ustedes", "Ellos", or "Ellas", the reflexive pronoun is "Se".',
                  'The reflexive pronoun typically comes before the verb (e.i. "Yo me lavo" for "I wash myself") in most cases.',
                  'However, when using a compound verb (more than one verb at once), the reflexive pronoun is added onto the end of the last verb.',
                  'For example, "Necesitas lavarte las manos" for "You need to wash your hands".',]

# %%
texts= [text_Structure, text_Gender, text_Demonstrative, text_Present_Tense, 
                text_Ser_Estar, text_Possessive, text_Reflexive]


#constructs a basic window, sets title, geometry
#window = Tk()
#window.title("Estudio Application") 
#window.geometry('350x200')
#main_window_geometry = [350, 200]
#center_x= (main_window_geometry[0])/2 
#print center_x
#window.mainloop()
#trying to implement foreign class for switch_frame which destroys a frame and switches to another
#edit, frame is no longer destoryed, it is replaced
class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        self.title('Spedish')
        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")
        self.geometry("700x600")
        # the container is where we'll stack a bunch of frames
        # on top of each other, then the one we want visible
        # will be raised above the others
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(300, weight=1)
        container.grid_columnconfigure(300, weight=1)
        


        self.frames = {}
        for F in (MainMenu, Flashcards, Lessons 
                 ):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame

            # put all of the pages in the same location;
            # the one on the top of the stacking order
            # will be the one that is visible.
            
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("MainMenu")

    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()

    #def close_window(self, page_name):
        #'''Destroy a frame for the given page name'''
        #frame = self.frames[page_name]
        #frame.destroy()
        
class MainMenu(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        
        self.controller = controller
        label = tk.Label(self, text="Main Menu", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)

        
        button2 = tk.Button(self, text="Flashcards",
                           command=lambda: controller.show_frame("Flashcards"))
        
       
        
        button1 = tk.Button(self, text="Lessons",
                           command=lambda: controller.show_frame("Lessons")) 
       
        
        
        
       
        
        button1.pack()
        button2.pack()
        
        
        
        #button that closes application
        #btn_op_exit = tk.Button(self, text="Exit", 
        #                     bg="red", 
        #                     fg="black",  
        #                     activebackground="green",
        #                     command=lambda: controller.close_window(""))
        #btn_op_exit.grid(column=center_x, row=6)
        #btn_op_exit.place(x=175, y=130, anchor="center")




class Flashcards(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        
        self.controller = controller
        label = tk.Label(self, text="Flashcards", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        
        introduce= tk.Text(self, height=5,
                     wrap=WORD)
        
        introduce.insert(INSERT, 
                         "You have selected the flashcards option. Flashcards are visual learning aids that enhance a user's memory of small topics. Each flashcard possesses a word (on its first side) and its direct translation (on its second side).")
        introduce.insert(END,
                         "\n\nPlease select a vocabulary section and gamemode before clicking the start button")
        x= ''
        
        def sel():
            exn=0
            if(var.get()==1):
                extext= "Spanish to English" 
            elif(var.get()==2):
                extext= "English to Spanish" 
            elif(var.get()==3):
                extext= "Mixed" 
            
            x = str(VLB.curselection())
            heldval= int(x[1:2])  
            
            #selection = "\nYou Selected Option #" + str(var.get())+ ": "+extext+ "\n"+ str(int(x[1:2]))
            
            #selectlabel.config(text = selection)
            #gameval=var.get()
            
            
            
        radlabel= tk.Label(self, text="\nGamemode Select:")
        radlabel2 = tk.Label(self, text="\nVocabulary Select:")
        
        var = IntVar()
        GR1 = Radiobutton(self, text="Spanish to English", variable=var, value=1,
                  command=sel)
        GR2 = Radiobutton(self, text="English to Spanish", variable=var, value=2,
                  command=sel)
        GR3 = Radiobutton(self, text="Mixed", variable=var, value=3,
                  command=sel)
        #'school work', 'greetings & personal info', 'descriptions', 'numbers', 'family',
        #'health', 'class subjects', 'hobbies', 'routines', 'navigation',
        #'art', 'science & technology', 'medical', 'society', 'government',
        #'nature', 'conventional sports', 'activities'
        
        val= IntVar()
        scrollbar = tk.Scrollbar(self, width =30)
        scrollbar.pack(side = RIGHT, fill = Y )

        VLB= tk.Listbox(self, width= 45,
                        selectmode=SINGLE, yscrollcommand= scrollbar.set
                       )
        
        VLB.insert(0, 'School Work')
        VLB.insert(1, 'Greetings')
        VLB.insert(2, 'Descriptions')
        VLB.insert(3, 'Numbers')
        VLB.insert(4, 'Family')
        VLB.insert(5, 'Health')
        VLB.insert(6, 'Class Subjects')
        VLB.insert(7, 'Hobbies')
        VLB.insert(8, 'Routine')
        VLB.insert(9, 'Navigation')
        VLB.insert(10, 'Art')
        VLB.insert(11, 'Science + Technology')
        VLB.insert(12, 'Medical')
        VLB.insert(13, 'Society')
        VLB.insert(14, 'Government')
        VLB.insert(15, 'Nature')
        VLB.insert(16, 'Conventional Sports')
        VLB.insert(17, 'Activities')
        
        VLBlist= ['school work', 'greetings & personal info', 'descriptions', 'numbers', 'family',
                    'health', 'class subjects', 'hobbies', 'routines', 'navigation',
                    'art', 'science & technology', 'medical', 'society', 'government',
                    'nature', 'conventional sports', 'activities']
        
        
        startbutton = tk.Button(self, text= "Start",
                            command=lambda: [startbutton.pack_forget(), VLB.pack_forget(),
                                            GR1.pack_forget(), GR2.pack_forget(), GR3.pack_forget(),
                                             radlabel.pack_forget(), radlabel2.pack_forget(), introduce.pack_forget(), 
                                             scrollbar.pack_forget()
                                            ])
        
        backbutton = tk.Button(self, text="Back",
                           command=lambda: [ scrollbar.pack(side = RIGHT, fill = Y ), introduce.pack(),
                                radlabel.pack(),
                                GR1.pack( anchor = S ),
                                GR2.pack( anchor = S ),
                                GR3.pack( anchor = S ),
                                radlabel2.pack(),
                                VLB.pack(),
                                #selectlabel.pack(),
                                startbutton.pack(),
                                backbutton.pack(),
                                controller.show_frame("MainMenu")])
        
        introduce.pack()
        radlabel.pack()
        GR1.pack( anchor = S )
        GR2.pack( anchor = S )
        GR3.pack( anchor = S )
        radlabel2.pack()
        VLB.pack()
        
        scrollbar.config( command = VLB.yview )
        
        #selectlabel.pack()
        startbutton.pack()
        backbutton.pack()
       
        lists = [words_School_Work, words_Greetings, words_Descriptions, words_Numbers, words_Family, 
         words_Health, words_Class_Subjects, words_Hobbies, words_Routines, words_Navigation,
        words_Art, words_Science_Tech, words_Medical, words_Society, words_Government, words_Nature,
         words_Conventional_Sports, words_Activities]
    
        questionlabel = tk.Label(self, text= '', font=controller.title_font)
        answerlabel = tk.Label(self, text= '', font=controller.title_font)
        inter1= ''
        inter2= ''
        
        global counter
        counter=0
        
        
        def clicked():
            inter1 = lists[0].keys()[counter]
            inter2 = lists[0].values()[counter]
            questionlabel.pack()
            
            questionlabel.config(text= inter1)
            answerlabel.config(text = inter2)
            global counter
            counter +=1
            
        
        
        nextbutton =  tk.Button(self, text="Flip",
                           command= clicked() )
        nextquestion = tk.Button(self, text= "Next Question", 
                                command=lambda: [questionlabel.forget_pack(), answerlabel.forget_pack()])
        nextbutton.pack()
        nextquestion.pack()
        
        global setval 
        
        
        
        
            
        
        
        
            
        
        
            
        
class Lessons(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        
        self.controller = controller
        label = tk.Label(self, text="Lessons", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        
        
        
        introduce= tk.Text(self, height=5,
                     wrap=WORD)
        
        introduce.insert(INSERT, 
                         "You have selected the lessons option.")
        introduce.insert(END,
                         "\n\nPlease select a lesson [1. text_Structure, 2. text_Gender, 3. text_Demonstrative, 4. text_Present_Tense, 5. text_Ser_Estar, 6. text_Possessive, 7. text_Reflexive]")
        introduce.pack()
        
        numb = 0
        var= IntVar()
        array= texts[numb]
        scrollbar = tk.Scrollbar(self, width =30)
        scrollbar.pack(side = RIGHT, fill = Y )
        textte = tk.Text(self,
                     wrap=WORD, yscrollcommand= scrollbar.set)
        def sel():
            
            numb= var.get()
            array= texts[numb]
            textte.insert(INSERT, 
                         array)
            introduce.destroy()
            
            
        GR1 = Radiobutton(self, text="1", variable=var, value=0,
                  command=sel)
        GR2 = Radiobutton(self, text="2", variable=var, value=1,
                  command=sel)
        GR3 = Radiobutton(self, text="3", variable=var, value=2,
                  command=sel)
        GR4 = Radiobutton(self, text="4", variable=var, value=3,
                  command=sel)
        GR5 = Radiobutton(self, text="5", variable=var, value=4,
                  command=sel)
        GR6 = Radiobutton(self, text="6", variable=var, value=5,
                  command=sel)
        
        GR7 = Radiobutton(self, text="7", variable=var, value=6,
                  command=sel)
        
        
        
        GR1.pack()
        GR2.pack()
        GR3.pack()
        GR4.pack()
        GR5.pack()
        GR6.pack()
        GR7.pack()
        
        
        button = tk.Button(self, text="Back",
                           command=lambda: [textte.destroy, controller.show_frame("MainMenu")])
       
            
            
         
        
        
        textte.pack()
            
            
            
            

        button.pack()
        
        
if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()




#lb_op = Label(window, text="Welcome to Estudio", font=("Arial Bold", 20))
#lb_op.grid(column=0, row=0)
#lb_op.place(x=175, y=20, anchor="center")

#creates button which will progress towards the secondary menu, sets position on window
#btn_op_start = Button(window, text="Start", 
#                      bg="red", 
#                      fg="black", 
#                      relief=RAISED, 
#                      activebackground="green"                    
#                     )
#btn_op_start.grid(column=center_x, row=4)
#btn_op_start.place(x=175, y=70, anchor="center")

#creates button which progresses towards a menu possessing options for the user to change
#btn_op_options = Button(window, text="Options", 
#                        bg="yellow", 
#                        fg="black", 
#                        relief=RAISED, 
#                        activebackground="green",                      
#                       )
#btn_op_options.grid(column=center_x, row=5)
#btn_op_options.place(x=175, y=100, anchor="center")

#function called by exit application buttons which will close the window
#def close_window(): 
#    window.destroy()
#button that closes application
#btn_op_exit = Button(window, text="Exit", 
#                     bg="red", 
#                     fg="black", 
#                     relief=RAISED, 
#                     activebackground="green",
#                    command=close_window)
#btn_op_exit.grid(column=center_x, row=6)
#btn_op_exit.place(x=175, y=130, anchor="center")
# Out:
# <ipython-input-103-a8c1410a5399>:236: SyntaxWarning: name 'counter' is used prior to global declaration
#   global counter
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\yusef\Anaconda2\lib\lib-tk\Tkinter.py", line 1541, in __call__
#     return self.func(*args)
#   File "<ipython-input-103-a8c1410a5399>", line 243, in <lambda>
#     command=lambda: [questionlabel.forget_pack(), answerlabel.forget_pack()])
# AttributeError: Label instance has no attribute 'forget_pack'

# %%
school = vocabulary_Lesson('School Work', words_School_Work)
#school.display_Contents()
#school.print_Subject()
#school.start_Flashcards()
greetings = vocabulary_Lesson('Greetings', words_Greetings)
descriptions = vocabulary_Lesson('Descriptions', words_Descriptions)
numbers = vocabulary_Lesson('Numbers', words_Numbers)
family = vocabulary_Lesson('Family', words_Family)
health = vocabulary_Lesson('Health', words_Health)
class_subjects = vocabulary_Lesson('Class Subjects', words_Class_Subjects)
hobbies = vocabulary_Lesson('Hobbies', words_Hobbies)
routines = vocabulary_Lesson('Routines', words_Routines)
navigation = vocabulary_Lesson('Navigation', words_Navigation)
art = vocabulary_Lesson('Art', words_Art)
science_and_technology = vocabulary_Lesson('Science & Technology', words_Science_Tech)
medical = vocabulary_Lesson('Medical', words_Medical)
society = vocabulary_Lesson('Society', words_Society)
government = vocabulary_Lesson('Government', words_Government)
nature = vocabulary_Lesson('Nature', words_Nature)
conventional_sports= vocabulary_Lesson('Conventional Sports', words_Conventional_Sports)
activities = vocabulary_Lesson('Activities', words_Activities)
print words_School_Work.items()
print words_School_Work.items()[0]
print words_School_Work.keys()[0]
print words_School_Work.values()[0]
print len(words_School_Work)
lists = [words_School_Work, words_Greetings, words_Descriptions, words_Numbers, words_Family, 
         words_Health, words_Class_Subjects, words_Hobbies, words_Routines, words_Navigation,
        words_Art, words_Science_Tech, words_Medical, words_Society, words_Government, words_Nature,
         words_Conventional_Sports, words_Activities
        ]
print lists[0].keys()[0]
print ''
value= 0
dic= lists[0] 
ind=0
for cards in dic: 
    if (cards == dic.keys()[0]):
        print cards
        ind=ind+1
